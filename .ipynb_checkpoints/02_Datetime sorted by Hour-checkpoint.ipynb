# %%
import pandas as pd
import os

# %%
basepath = "./cleaned_data/"
futurepath = "./hourly_data/"
for filename in os.listdir(basepath):
    if filename.endswith(".csv"): 
        ride = os.path.join("." +filename)
        ride = pd.read_csv(basepath + filename)
        print(ride.dtypes)
        ride['date'] = pd.to_datetime(ride["date"])
        ride['datetime'] = pd.to_datetime(ride["datetime"])
        ride = ride[~(ride['date'] < '2015-01-01')]
        ride = ride[~(ride['date'] > '2019-12-30')]
        print(ride.dtypes)
        ride.set_index('datetime', inplace = True)
        ride = ride.resample("H").mean().round().dropna()
        ride.reset_index(level=0, inplace=True)
        print(ride.info())        
        ride.to_csv('./hourly_data/' + filename, index = False)
        print(f'{filename} is averaged by hour and is now in the hourly_data folder')
# Out:
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28140 entries, 0 to 28139
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  28140 non-null  datetime64[ns]
#  1   SPOSTMIN  28140 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 439.8 KB
# None
# 7_dwarfs_train.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24907 entries, 0 to 24906
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  24907 non-null  datetime64[ns]
#  1   SPOSTMIN  24907 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 389.3 KB
# None
# pirates_of_caribbean.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25257 entries, 0 to 25256
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  25257 non-null  datetime64[ns]
#  1   SPOSTMIN  25257 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 394.8 KB
# None
# spaceship_earth.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24629 entries, 0 to 24628
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  24629 non-null  datetime64[ns]
#  1   SPOSTMIN  24629 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 385.0 KB
# None
# splash_mountain.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24865 entries, 0 to 24864
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  24865 non-null  datetime64[ns]
#  1   SPOSTMIN  24865 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 388.6 KB
# None
# toy_story_mania.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23646 entries, 0 to 23645
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  23646 non-null  datetime64[ns]
#  1   SPOSTMIN  23646 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 369.6 KB
# None
# soarin.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22636 entries, 0 to 22635
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  22636 non-null  datetime64[ns]
#  1   SPOSTMIN  22636 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 353.8 KB
# None
# kilimanjaro_safaris.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23194 entries, 0 to 23193
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  23194 non-null  datetime64[ns]
#  1   SPOSTMIN  23194 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 362.5 KB
# None
# expedition_everest.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24743 entries, 0 to 24742
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  24743 non-null  datetime64[ns]
#  1   SPOSTMIN  24743 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 386.7 KB
# None
# rock_n_rollercoaster.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21437 entries, 0 to 21436
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  21437 non-null  datetime64[ns]
#  1   SPOSTMIN  21437 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 335.1 KB
# None
# dinosaur.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13587 entries, 0 to 13586
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  13587 non-null  datetime64[ns]
#  1   SPOSTMIN  13587 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 212.4 KB
# None
# flight_of_passage.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13422 entries, 0 to 13421
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  13422 non-null  datetime64[ns]
#  1   SPOSTMIN  13422 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 209.8 KB
# None
# navi_river.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7928 entries, 0 to 7927
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  7928 non-null   datetime64[ns]
#  1   SPOSTMIN  7928 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 124.0 KB
# None
# alien_saucers.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7872 entries, 0 to 7871
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  7872 non-null   datetime64[ns]
#  1   SPOSTMIN  7872 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 123.1 KB
# None
# slinky_dog.csv is averaged by hour and is now in the hourly_data folder
