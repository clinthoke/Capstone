# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Import Hollywood Studios attractions
hsa = pd.read_csv("../attractions/attractions_hs.csv")
hsa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31039 entries, 0 to 31038
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              31039 non-null  object
#  1   toy_story_mania       31039 non-null  object
#  2   rock_n_rollercoaster  31039 non-null  object
#  3   alien_saucers         31039 non-null  object
#  4   slinky_dog            31039 non-null  object
# dtypes: object(5)
# memory usage: 1.2+ MB

# %%
# Added DATE column to mk from the datetime column, using it to concat dataframes
hsa['DATE'] = pd.to_datetime(hsa['datetime']).dt.date
hsa['DATE'] = pd.to_datetime(hsa["DATE"])
print(hsa.info())
hsa.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31039 entries, 0 to 31038
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              31039 non-null  object
#  1   toy_story_mania       31039 non-null  object
#  2   rock_n_rollercoaster  31039 non-null  object
#  3   alien_saucers         31039 non-null  object
#  4   slinky_dog            31039 non-null  object
#  5   DATE                  31039 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(5)
# memory usage: 1.4+ MB
# None
#               datetime toy_story_mania rock_n_rollercoaster alien_saucers  \
# 0  2015-01-01 07:00:00            20.0                  5.0            na
# 1  2015-01-01 08:00:00            54.0                 25.0            na
#
#   slinky_dog       DATE
# 0         na 2015-01-01
# 1         na 2015-01-01

# %%
# Import Metadata
md = pd.read_csv("../metadata/hs_metadata.csv")
md.head(2)
# Out:
#          DATE  DAYOFWEEK  DAYOFYEAR  WEEKOFYEAR  MONTHOFYEAR  YEAR  HOLIDAYPX  \
# 0  2015-01-01          5          0           0            1  2015          0
# 1  2015-01-02          6          1           0            1  2015          2
#
#    HOLIDAYM  HOLIDAY  WDWevent  ...  HSHOURSYEST HSOPENTOM  HSCLOSETOM  \
# 0         5        1         0  ...         16.0      8:00       22:00
# 1         5        0         0  ...         14.0      9:00       22:00
#
#    HSHOURSTOM  WDWMINTEMP_mean  WEATHER_WDWHIGH WEATHER_WDWLOW  \
# 0        14.0        53.375714             70.3           50.2
# 1        13.0        53.750714             70.3           50.0
#
#   WEATHER_WDWPRECIP CapacityLost_HS CapacityLostWGT_HS
# 0              0.12          296273           26907827
# 1              0.12          296273           26907827
#
# [2 rows x 64 columns]

# %%
# Convert DATE column to datetime
md['DATE'] = pd.to_datetime(md["DATE"])
md.head(2)
# Out:
#         DATE  DAYOFWEEK  DAYOFYEAR  WEEKOFYEAR  MONTHOFYEAR  YEAR  HOLIDAYPX  \
# 0 2015-01-01          5          0           0            1  2015          0
# 1 2015-01-02          6          1           0            1  2015          2
#
#    HOLIDAYM  HOLIDAY  WDWevent  ...  HSHOURSYEST HSOPENTOM  HSCLOSETOM  \
# 0         5        1         0  ...         16.0      8:00       22:00
# 1         5        0         0  ...         14.0      9:00       22:00
#
#    HSHOURSTOM  WDWMINTEMP_mean  WEATHER_WDWHIGH WEATHER_WDWLOW  \
# 0        14.0        53.375714             70.3           50.2
# 1        13.0        53.750714             70.3           50.0
#
#   WEATHER_WDWPRECIP CapacityLost_HS CapacityLostWGT_HS
# 0              0.12          296273           26907827
# 1              0.12          296273           26907827
#
# [2 rows x 64 columns]

# %%
# Merge mka and md dataframes
hs = pd.merge(hsa, md, how='outer', on='DATE')
# Dropped unneeded Date column
hs.drop('DATE', axis = 1,  inplace = True)
# Set datetime to the Index and sorted by it
hs.set_index('datetime', inplace=True)
hs.sort_index(inplace=True)
hs.head(2)
# Out:
#                     toy_story_mania rock_n_rollercoaster alien_saucers  \
# datetime
# 2015-01-01 07:00:00            20.0                  5.0            na
# 2015-01-01 08:00:00            54.0                 25.0            na
#
#                     slinky_dog  DAYOFWEEK  DAYOFYEAR  WEEKOFYEAR  MONTHOFYEAR  \
# datetime
# 2015-01-01 07:00:00         na        5.0        0.0         0.0          1.0
# 2015-01-01 08:00:00         na        5.0        0.0         0.0          1.0
#
#                        YEAR  HOLIDAYPX  ...  HSHOURSYEST  HSOPENTOM  \
# datetime                                ...
# 2015-01-01 07:00:00  2015.0        0.0  ...         16.0       8:00
# 2015-01-01 08:00:00  2015.0        0.0  ...         16.0       8:00
#
#                      HSCLOSETOM  HSHOURSTOM WDWMINTEMP_mean  WEATHER_WDWHIGH  \
# datetime
# 2015-01-01 07:00:00       22:00        14.0       53.375714             70.3
# 2015-01-01 08:00:00       22:00        14.0       53.375714             70.3
#
#                      WEATHER_WDWLOW  WEATHER_WDWPRECIP  CapacityLost_HS  \
# datetime
# 2015-01-01 07:00:00            50.2               0.12         296273.0
# 2015-01-01 08:00:00            50.2               0.12         296273.0
#
#                     CapacityLostWGT_HS
# datetime
# 2015-01-01 07:00:00         26907827.0
# 2015-01-01 08:00:00         26907827.0
#
# [2 rows x 67 columns]

# %%
for col in ['HSOPEN','HSCLOSE','HSEMHOPEN', 'HSEMHCLOSE',
       'HSOPENYEST', 'HSCLOSEYEST', 'HSOPENTOM',
       'HSCLOSETOM','SUNSET_WDW']:
    hs[col] = np.where(hs[col] == "24:00",'23:59' ,hs[col])
    hs[col] = np.where(hs[col] == "27:00",'23:59' ,hs[col])
    hs[col] = np.where(hs[col] == "26:00",'23:59' ,hs[col])
    hs[col] = np.where(hs[col] == "25:00",'23:59' ,hs[col])
    hs[col] = np.where(hs[col] == "23:55",'23:59' ,hs[col])
    hs[col] = np.where(hs[col] == "29:59",'23:59' ,hs[col])
    hs[col] = np.where(hs[col] == "30:00",'23:59' ,hs[col])

# %%
for col in ['HSOPEN', 'HSCLOSE',  'HSEMHOPEN', 'HSEMHCLOSE',
       'HSOPENYEST', 'HSCLOSEYEST', 'HSOPENTOM',
       'HSCLOSETOM','SUNSET_WDW']:
    hs[col] = hs[col].str.replace(":","")

# %%
hs.fillna(0, inplace=True)
hs.isnull().sum()
# Out:
# toy_story_mania         0
# rock_n_rollercoaster    0
# alien_saucers           0
# slinky_dog              0
# DAYOFWEEK               0
#                        ..
# WEATHER_WDWHIGH         0
# WEATHER_WDWLOW          0
# WEATHER_WDWPRECIP       0
# CapacityLost_HS         0
# CapacityLostWGT_HS      0
# Length: 67, dtype: int64

# %%
for col in ['HSOPEN', 'HSCLOSE',  'HSEMHOPEN', 'HSEMHCLOSE',
       'HSOPENYEST', 'HSCLOSEYEST', 'HSOPENTOM',
       'HSCLOSETOM','SUNSET_WDW']:
    hs[col] = hs[col].astype(int)

# %%
for col in ['inSession', 'inSession_Enrollment', 'inSession_wdw',
       'inSession_sqrt_WDW', 'inSession_DC', 'inSession_Central_FL',
       'inSession_Drive1_FL', 'inSession_Drive2_FL',
       'inSession_Florida', 'inSession_Mardi_Gras', 'inSession_Midwest',
       'inSession_NY_NJ', 'inSession_NY_NJ_PA', 'inSession_New_England',
       'inSession_New_Jersey', 'inSession_Nothwest', 'INSESSION_PLANES',
       'inSession_SoCal', 'inSession_Southwest']:
    hs[col] = hs[col].str.replace(r'%', r'').astype('float')/-100

# %%
for col in ['toy_story_mania','rock_n_rollercoaster','alien_saucers', 'slinky_dog']:
    hs[col] = pd.to_numeric(hs[col],errors='coerce')
hs.fillna(0, inplace=True)

# %%
# Dummified the WDWSEASON column
hs = pd.get_dummies(hs,columns = ['WDWSEASON'])

# %%
# Created new column for hour as a feature
hs['hour'] = hs.index
hs['hour'] = hs.hour.str[11:13]
hs['hour'] = pd.to_numeric(hs['hour'])*100
hs.tail(5)
# Out:
#                      toy_story_mania  rock_n_rollercoaster  alien_saucers  \
# datetime
# 2019-12-30 21:00:00             23.0                  42.0           20.0
# 2019-12-30 22:00:00              0.0                   0.0            0.0
# 2019-12-30 23:00:00              0.0                   0.0            0.0
# 2019-12-31 00:00:00              0.0                   0.0            0.0
# 2019-12-31 01:00:00              0.0                   0.0            0.0
#
#                      slinky_dog  DAYOFWEEK  DAYOFYEAR  WEEKOFYEAR  \
# datetime
# 2019-12-30 21:00:00        46.0        2.0      363.0        52.0
# 2019-12-30 22:00:00         0.0        2.0      363.0        52.0
# 2019-12-30 23:00:00         0.0        2.0      363.0        52.0
# 2019-12-31 00:00:00         0.0        0.0        0.0         0.0
# 2019-12-31 01:00:00         0.0        0.0        0.0         0.0
#
#                      MONTHOFYEAR    YEAR  HOLIDAYPX  ...  \
# datetime                                             ...
# 2019-12-30 21:00:00         12.0  2019.0        2.0  ...
# 2019-12-30 22:00:00         12.0  2019.0        2.0  ...
# 2019-12-30 23:00:00         12.0  2019.0        2.0  ...
# 2019-12-31 00:00:00          0.0     0.0        0.0  ...
# 2019-12-31 01:00:00          0.0     0.0        0.0  ...
#
#                      WDWSEASON_MARDI GRAS  \
# datetime
# 2019-12-30 21:00:00                     0
# 2019-12-30 22:00:00                     0
# 2019-12-30 23:00:00                     0
# 2019-12-31 00:00:00                     0
# 2019-12-31 01:00:00                     0
#
#                      WDWSEASON_MARTIN LUTHER KING JUNIOR DAY  \
# datetime
# 2019-12-30 21:00:00                                        0
# 2019-12-30 22:00:00                                        0
# 2019-12-30 23:00:00                                        0
# 2019-12-31 00:00:00                                        0
# 2019-12-31 01:00:00                                        0
#
#                      WDWSEASON_MEMORIAL DAY  WDWSEASON_PRESIDENTS WEEK  \
# datetime
# 2019-12-30 21:00:00                       0                          0
# 2019-12-30 22:00:00                       0                          0
# 2019-12-30 23:00:00                       0                          0
# 2019-12-31 00:00:00                       0                          0
# 2019-12-31 01:00:00                       0                          0
#
#                      WDWSEASON_SEPTEMBER LOW  WDWSEASON_SPRING  \
# datetime
# 2019-12-30 21:00:00                        0                 0
# 2019-12-30 22:00:00                        0                 0
# 2019-12-30 23:00:00                        0                 0
# 2019-12-31 00:00:00                        0                 0
# 2019-12-31 01:00:00                        0                 0
#
#                      WDWSEASON_SUMMER BREAK  WDWSEASON_THANKSGIVING  \
# datetime
# 2019-12-30 21:00:00                       0                       0
# 2019-12-30 22:00:00                       0                       0
# 2019-12-30 23:00:00                       0                       0
# 2019-12-31 00:00:00                       0                       0
# 2019-12-31 01:00:00                       0                       0
#
#                      WDWSEASON_WINTER  hour
# datetime
# 2019-12-30 21:00:00                 0  2100
# 2019-12-30 22:00:00                 0  2200
# 2019-12-30 23:00:00                 0  2300
# 2019-12-31 00:00:00                 0     0
# 2019-12-31 01:00:00                 0   100
#
# [5 rows x 85 columns]

# %%
hs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31039 entries, 2015-01-01 07:00:00 to 2019-12-31 01:00:00
# Data columns (total 85 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   toy_story_mania                          31039 non-null  float64
#  1   rock_n_rollercoaster                     31039 non-null  float64
#  2   alien_saucers                            31039 non-null  float64
#  3   slinky_dog                               31039 non-null  float64
#  4   DAYOFWEEK                                31039 non-null  float64
#  5   DAYOFYEAR                                31039 non-null  float64
#  6   WEEKOFYEAR                               31039 non-null  float64
#  7   MONTHOFYEAR                              31039 non-null  float64
#  8   YEAR                                     31039 non-null  float64
#  9   HOLIDAYPX                                31039 non-null  float64
#  10  HOLIDAYM                                 31039 non-null  float64
#  11  HOLIDAY                                  31039 non-null  float64
#  12  WDWevent                                 31039 non-null  float64
#  13  WDWrace                                  31039 non-null  float64
#  14  WDWMAXTEMP                               31039 non-null  float64
#  15  WDWMINTEMP                               31039 non-null  float64
#  16  WDWMEANTEMP                              31039 non-null  float64
#  17  HSevent                                  31039 non-null  float64
#  18  inSession                                31039 non-null  float64
#  19  inSession_Enrollment                     31039 non-null  float64
#  20  inSession_wdw                            31039 non-null  float64
#  21  inSession_sqrt_WDW                       31039 non-null  float64
#  22  inSession_California                     31039 non-null  object
#  23  inSession_DC                             31039 non-null  float64
#  24  inSession_Central_FL                     31039 non-null  float64
#  25  inSession_Drive1_FL                      31039 non-null  float64
#  26  inSession_Drive2_FL                      31039 non-null  float64
#  27  inSession_Drive_CA                       31039 non-null  object
#  28  inSession_Florida                        31039 non-null  float64
#  29  inSession_Mardi_Gras                     31039 non-null  float64
#  30  inSession_Midwest                        31039 non-null  float64
#  31  inSession_NY_NJ                          31039 non-null  float64
#  32  inSession_NY_NJ_PA                       31039 non-null  float64
#  33  inSession_New_England                    31039 non-null  float64
#  34  inSession_New_Jersey                     31039 non-null  float64
#  35  inSession_Nothwest                       31039 non-null  float64
#  36  INSESSION_PLANES                         31039 non-null  float64
#  37  inSession_SoCal                          31039 non-null  float64
#  38  inSession_Southwest                      31039 non-null  float64
#  39  SUNSET_WDW                               31039 non-null  int64
#  40  HSEMHMORN                                31039 non-null  float64
#  41  HSEMHMYEST                               31039 non-null  float64
#  42  HSEMHMTOM                                31039 non-null  float64
#  43  HSEMHEVE                                 31039 non-null  float64
#  44  HSEMHEYEST                               31039 non-null  float64
#  45  HSEMHETOM                                31039 non-null  float64
#  46  HSHOURSEMH                               31039 non-null  float64
#  47  HSHOURSEMHYEST                           31039 non-null  float64
#  48  HSHOURSEMHTOM                            31039 non-null  float64
#  49  HSOPEN                                   31039 non-null  int64
#  50  HSCLOSE                                  31039 non-null  int64
#  51  HSHOURS                                  31039 non-null  float64
#  52  HSEMHOPEN                                31039 non-null  int64
#  53  HSEMHCLOSE                               31039 non-null  int64
#  54  HSOPENYEST                               31039 non-null  int64
#  55  HSCLOSEYEST                              31039 non-null  int64
#  56  HSHOURSYEST                              31039 non-null  float64
#  57  HSOPENTOM                                31039 non-null  int64
#  58  HSCLOSETOM                               31039 non-null  int64
#  59  HSHOURSTOM                               31039 non-null  float64
#  60  WDWMINTEMP_mean                          31039 non-null  float64
#  61  WEATHER_WDWHIGH                          31039 non-null  float64
#  62  WEATHER_WDWLOW                           31039 non-null  float64
#  63  WEATHER_WDWPRECIP                        31039 non-null  float64
#  64  CapacityLost_HS                          31039 non-null  float64
#  65  CapacityLostWGT_HS                       31039 non-null  float64
#  66  WDWSEASON_0                              31039 non-null  uint8
#  67  WDWSEASON_CHRISTMAS                      31039 non-null  uint8
#  68  WDWSEASON_CHRISTMAS PEAK                 31039 non-null  uint8
#  69  WDWSEASON_COLUMBUS DAY                   31039 non-null  uint8
#  70  WDWSEASON_EASTER                         31039 non-null  uint8
#  71  WDWSEASON_FALL                           31039 non-null  uint8
#  72  WDWSEASON_HALLOWEEN                      31039 non-null  uint8
#  73  WDWSEASON_JERSEY WEEK                    31039 non-null  uint8
#  74  WDWSEASON_JULY 4TH                       31039 non-null  uint8
#  75  WDWSEASON_MARDI GRAS                     31039 non-null  uint8
#  76  WDWSEASON_MARTIN LUTHER KING JUNIOR DAY  31039 non-null  uint8
#  77  WDWSEASON_MEMORIAL DAY                   31039 non-null  uint8
#  78  WDWSEASON_PRESIDENTS WEEK                31039 non-null  uint8
#  79  WDWSEASON_SEPTEMBER LOW                  31039 non-null  uint8
#  80  WDWSEASON_SPRING                         31039 non-null  uint8
#  81  WDWSEASON_SUMMER BREAK                   31039 non-null  uint8
#  82  WDWSEASON_THANKSGIVING                   31039 non-null  uint8
#  83  WDWSEASON_WINTER                         31039 non-null  uint8
#  84  hour                                     31039 non-null  int64
# dtypes: float64(55), int64(10), object(2), uint8(18)
# memory usage: 16.6+ MB

# %%
top_corr = hs.corr()
top_corr_features = top_corr.index[abs(top_corr["alien_saucers"]) > .15]
plt.figure(figsize=(20,20))
g = sns.heatmap(hs[top_corr_features].corr(),annot=True,cmap="magma")

# %%
corr = hs.corr()
plt.figure(figsize = (6,18))
sns.heatmap(corr[['alien_saucers']].sort_values(by = 'alien_saucers', ascending = False).head(85),vmin = 0, annot = True)
plt.show()

# %%
import numpy as np
from math import sqrt
from sklearn.datasets import make_classification, make_regression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GRU
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from sklearn.linear_model import LinearRegression
from datetime import date
from sklearn import metrics
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
import statsmodels.api as sm

# %%
from math import sqrt
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, BaggingRegressor
from sklearn.linear_model import Ridge, RidgeCV, LinearRegression, LogisticRegression, Lasso, LassoCV
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.ensemble import BaggingRegressor, BaggingClassifier, RandomForestRegressor, RandomForestClassifier, AdaBoostRegressor, AdaBoostClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.metrics import mean_squared_error
from sklearn.metrics import f1_score
from sklearn import svm

# %%
#
features = ['rock_n_rollercoaster','toy_story_mania',
             'slinky_dog',
            'inSession','YEAR', 'HSHOURS', 'DAYOFWEEK','HOLIDAYM',
            'WDWSEASON_CHRISTMAS', 'WDWSEASON_CHRISTMAS PEAK', 'HSOPEN',
       'WDWSEASON_COLUMBUS DAY', 'WDWSEASON_EASTER', 'WDWSEASON_FALL',
       'WDWSEASON_HALLOWEEN', 'WDWSEASON_JERSEY WEEK', 'WDWSEASON_JULY 4TH',
       'WDWSEASON_MARDI GRAS', 'WDWSEASON_MARTIN LUTHER KING JUNIOR DAY',
       'WDWSEASON_MEMORIAL DAY', 'WDWSEASON_PRESIDENTS WEEK',
       'WDWSEASON_SEPTEMBER LOW', 'WDWSEASON_SPRING', 'WDWSEASON_SUMMER BREAK',
       'WDWSEASON_THANKSGIVING', 'WDWSEASON_WINTER', 'hour','CapacityLostWGT_HS']
y = hs['alien_saucers']
X = hs[features]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =.02, random_state=21)
sc = StandardScaler()
sc.fit(X_train)
X_train_sc = sc.transform(X_train)
X_test_sc = sc.transform(X_test)

# %%
# Created my model and started the train test split
linreg = LinearRegression()
linreg.fit(X_train_sc, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
linreg_preds_train = linreg.predict(X_train_sc)
linreg_rms_train = sqrt(mean_squared_error(y_train, linreg_preds_train))
linreg_rms_train
# Out:
# 5.239663011331036

# %%
linreg_preds_test = linreg.predict(X_test_sc)
linreg_rms_test = sqrt(mean_squared_error(y_test, linreg_preds_test))
linreg_rms_test
# Out:
# 5.989098537579552

# %% [markdown]
# ## KNN

# %%
# Instiantiated KNN and fitted the training
knn = KNeighborsRegressor()
knn.fit(X_train_sc, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform')

# %%
knn_preds_train = knn.predict(X_train_sc)
knn_rms_train = sqrt(mean_squared_error(y_train, knn_preds_train))
knn_rms_train
# Out:
# 3.245871050172929

# %%
knn_preds_test = knn.predict(X_test_sc)
knn_rms_test = sqrt(mean_squared_error(y_test, knn_preds_test))
knn_rms_test
# Out:
# 4.164569520546557

# %% [markdown]
# ## Decision Tree Model

# %%
# Instiantiate model and fit
dt = DecisionTreeRegressor()
dt.fit(X_train_sc, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
dt_preds_train = dt.predict(X_train_sc)
dt_rms_train = sqrt(mean_squared_error(y_train, dt_preds_train))
dt_rms_train
# Out:
# 0.0

# %%
dt_preds_test = dt.predict(X_test_sc)
dt_rms_test = sqrt(mean_squared_error(y_test, dt_preds_test))
dt_rms_test
# Out:
# 5.527270993689486

# %% [markdown]
# ## Bagged Decision Tree

# %%
# Instiantiate model and fit
bag = BaggingRegressor()
bag.fit(X_train_sc, y_train)
# Out:
# BaggingRegressor(base_estimator=None, bootstrap=True, bootstrap_features=False,
#                  max_features=1.0, max_samples=1.0, n_estimators=10,
#                  n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                  warm_start=False)

# %%
bag_preds_train = bag.predict(X_train_sc)
bag_rms_train = sqrt(mean_squared_error(y_train, bag_preds_train))
bag_rms_train
# Out:
# 1.535284049793779

# %%
bag_preds_test = bag.predict(X_test_sc)
bag_rms_test = sqrt(mean_squared_error(y_test, bag_preds_test))
bag_rms_test
# Out:
# 4.479171694188842

# %% [markdown]
# ## Random Forests

# %%
# Instiantiate model and fit
rf = RandomForestRegressor()
rf.fit(X_train_sc, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
rf_preds_train = rf.predict(X_train_sc)
rf_rms_train = sqrt(mean_squared_error(y_train, rf_preds_train))
rf_rms_train
# Out:
# 1.3186331280230836

# %%
rf_preds_test = rf.predict(X_test_sc)
rf_rms_test = sqrt(mean_squared_error(y_test, rf_preds_test))
rf_rms_test
# Out:
# 4.162395027763433

# %% [markdown]
# ## ADA boost

# %%
# Instiantiate model and fit
ada = AdaBoostRegressor()
ada.fit(X_train_sc, y_train)
# Out:
# AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#                   n_estimators=50, random_state=None)

# %%
ada_preds_train = dt.predict(X_train_sc)
ada_rms_train = sqrt(mean_squared_error(y_train, ada_preds_train))
ada_rms_train
# Out:
# 0.0

# %%
ada_preds_test = ada.predict(X_test_sc)
ada_rms_test = sqrt(mean_squared_error(y_test, ada_preds_test))
ada_rms_test
# Out:
# 9.951876780901713

# %% [markdown]
# ## SVM

# %%
# Instiantiate model and fit
svr = svm.SVR()
svr.fit(X_train_sc, y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
svr_preds_train = svr.predict(X_train_sc)
svr_rms_train = sqrt(mean_squared_error(y_train, svr_preds_train))
svr_rms_train
# Out:
# 5.293499067175144

# %%
svr_preds_test = svr.predict(X_test_sc)
svr_rms_test = sqrt(mean_squared_error(y_test, svr_preds_test))
svr_rms_test
# Out:
# 6.6500776058837285
