# %%
import pandas as pd

# %%
entities = pd.read_csv("entities.csv")
entities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   code                      103 non-null    object
#  1   name                      103 non-null    object
#  2   short_name                103 non-null    object
#  3   land                      103 non-null    object
#  4   opened_on                 102 non-null    object
#  5   duration                  102 non-null    float64
#  6   average_wait_per_hundred  63 non-null     float64
# dtypes: float64(2), object(5)
# memory usage: 5.8+ KB

# %%
entities.head(60)
# Out:
#      code                                               name  \
# 0    AK07                                Kilimanjaro Safaris
# 1    AK11  Expedition Everest - Legend of the Forbidden M...
# 2    AK18                                           DINOSAUR
# 3    AK85                                Na'vi River Journey
# 4    AK86                           Avatar Flight of Passage
# 5    CA03        Monsters, Inc. Mike & Sulley to the Rescue!
# 6    CA06                  The Twilight Zone Tower of Terror
# 7    CA09                           Soarin' Around the World
# 8   CA109                            Radiator Springs Racers
# 9   CA110                          Mater's Junkyard Jamboree
# 10   CA12                                  Grizzly River Run
# 11  CA120          Radiator Springs Racers Single Rider Line
# 12  CA148                       Luigi's Rollickin' Roadsters
# 13   CA19                               California Screamin'
# ...
