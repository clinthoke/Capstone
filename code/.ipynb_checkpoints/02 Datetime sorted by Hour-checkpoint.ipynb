# %%
import pandas as pd
import os

# %%
basepath = "../cleaned_data/"
futurepath = "../hourly_data/"
for filename in os.listdir(basepath):
    if filename.endswith(".csv"): 
        ride = os.path.join("." +filename)
        ride = pd.read_csv(basepath + filename)
        print(ride.dtypes)
        ride['date'] = pd.to_datetime(ride["date"])
        ride['datetime'] = pd.to_datetime(ride["datetime"])
        mk = mk[~(mk.index < '2015-01-01')]
        print(ride.dtypes)
        ride.set_index('datetime', inplace = True)
        ride = ride.resample("H").mean().round().dropna()
        ride.reset_index(level=0, inplace=True)
        print(ride.info())        
#         ride.to_csv('../hourly_data/' + filename, index = False)
        print(f'{filename} is averaged by hour and is now in the hourly_data folder')
# Out:
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29174 entries, 0 to 29173
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  29174 non-null  datetime64[ns]
#  1   SPOSTMIN  29174 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 456.0 KB
# None
# 7_dwarfs_train.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25889 entries, 0 to 25888
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  25889 non-null  datetime64[ns]
#  1   SPOSTMIN  25889 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 404.6 KB
# None
# pirates_of_caribbean.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37636 entries, 0 to 37635
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  37636 non-null  datetime64[ns]
#  1   SPOSTMIN  37636 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 588.2 KB
# None
# spaceship_earth.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24899 entries, 0 to 24898
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  24899 non-null  datetime64[ns]
#  1   SPOSTMIN  24899 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 389.2 KB
# None
# splash_mountain.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25836 entries, 0 to 25835
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  25836 non-null  datetime64[ns]
#  1   SPOSTMIN  25836 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 403.8 KB
# None
# toy_story_mania.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37009 entries, 0 to 37008
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  37009 non-null  datetime64[ns]
#  1   SPOSTMIN  37009 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 578.4 KB
# None
# soarin.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32441 entries, 0 to 32440
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  32441 non-null  datetime64[ns]
#  1   SPOSTMIN  32441 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 507.0 KB
# None
# kilimanjaro_safaris.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34154 entries, 0 to 34153
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  34154 non-null  datetime64[ns]
#  1   SPOSTMIN  34154 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 533.8 KB
# None
# expedition_everest.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25712 entries, 0 to 25711
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  25712 non-null  datetime64[ns]
#  1   SPOSTMIN  25712 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 401.9 KB
# None
# rock_n_rollercoaster.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31649 entries, 0 to 31648
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  31649 non-null  datetime64[ns]
#  1   SPOSTMIN  31649 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 494.6 KB
# None
# dinosaur.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14519 entries, 0 to 14518
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  14519 non-null  datetime64[ns]
#  1   SPOSTMIN  14519 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 227.0 KB
# None
# flight_of_passage.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14351 entries, 0 to 14350
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  14351 non-null  datetime64[ns]
#  1   SPOSTMIN  14351 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 224.4 KB
# None
# navi_river.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8902 entries, 0 to 8901
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  8902 non-null   datetime64[ns]
#  1   SPOSTMIN  8902 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 139.2 KB
# None
# alien_saucers.csv is averaged by hour and is now in the hourly_data folder
# date         object
# datetime     object
# SPOSTMIN    float64
# dtype: object
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8839 entries, 0 to 8838
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  8839 non-null   datetime64[ns]
#  1   SPOSTMIN  8839 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 138.2 KB
# None
# slinky_dog.csv is averaged by hour and is now in the hourly_data folder
