# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 200)
pd.set_option('display.width', 100)

# %%
disney = pd.read_csv("metadata.csv")
disney.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3226 entries, 0 to 3225
# Columns: 190 entries, DATE to AKSHWNN
# dtypes: float64(34), int64(61), object(95)
# memory usage: 4.7+ MB

# %%
disney.shape
# Out:
# (3226, 190)

# %%
# Dropped duplicated rows
disney.drop_duplicates(inplace=True)
disney.shape
# Out:
# (2919, 190)

# %%
disney['DATE'] = pd.to_datetime(disney["DATE"])
disney = disney[~(disney['DATE'] < '2015-01-01')]

# %%
disney.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1823 entries, 1096 to 3225
# Columns: 190 entries, DATE to AKSHWNN
# dtypes: datetime64[ns](1), float64(34), int64(61), object(94)
# memory usage: 2.7+ MB

# %%
disney.T
# Out:
#                                                       1096                                 1097  \
# DATE                                   2015-01-01 00:00:00                  2015-01-02 00:00:00
# WDW_TICKET_SEASON                                      NaN                                  NaN
# DAYOFWEEK                                                5                                    6
# DAYOFYEAR                                                0                                    1
# WEEKOFYEAR                                               0                                    0
# MONTHOFYEAR                                              1                                    1
# YEAR                                                  2015                                 2015
# SEASON                                      CHRISTMAS PEAK                            CHRISTMAS
# HOLIDAYPX                                                0                                    2
# ...

# %%
disney.columns.values
# Out:
# array(['DATE', 'WDW_TICKET_SEASON', 'DAYOFWEEK', 'DAYOFYEAR',
#        'WEEKOFYEAR', 'MONTHOFYEAR', 'YEAR', 'SEASON', 'HOLIDAYPX',
#        'HOLIDAYM', 'HOLIDAYN', 'HOLIDAY', 'WDWTICKETSEASON', 'WDWRaceN',
#        'WDWeventN', 'WDWevent', 'WDWrace', 'WDWSEASON', 'WDWMAXTEMP',
#        'WDWMINTEMP', 'WDWMEANTEMP', 'MKeventN', 'MKevent', 'EPeventN',
#        'EPevent', 'HSeventN', 'HSevent', 'AKeventN', 'AKevent',
#        'HOLIDAYJ', 'inSession', 'inSession_Enrollment', 'inSession_wdw',
#        'inSession_dlr', 'inSession_sqrt_WDW', 'inSession_sqrt_DLR',
#        'inSession_California', 'inSession_DC', 'inSession_Central_FL',
#        'inSession_Drive1_FL', 'inSession_Drive2_FL', 'inSession_Drive_CA',
#        'inSession_Florida', 'inSession_Mardi_Gras', 'inSession_Midwest',
#        'inSession_NY_NJ', 'inSession_NY_NJ_PA', 'inSession_New_England',
#        'inSession_New_Jersey', 'inSession_Nothwest', 'INSESSION_PLANES',
# ...

# %%
mk_metadata = disney[['DATE',  'DAYOFWEEK', 'DAYOFYEAR',
       'WEEKOFYEAR', 'MONTHOFYEAR', 'YEAR', 'HOLIDAYPX',
       'HOLIDAYM', 'HOLIDAY',  'WDWevent', 'WDWrace', 
        'WDWSEASON', 'WDWMAXTEMP', 'WDWMINTEMP', 'WDWMEANTEMP', 'MKevent',
       'inSession', 'inSession_Enrollment', 'inSession_wdw',
       'inSession_sqrt_WDW', 'inSession_DC', 'inSession_Central_FL',
       'inSession_Drive1_FL', 'inSession_Drive2_FL',
       'inSession_Florida', 'inSession_Mardi_Gras', 'inSession_Midwest',
       'inSession_NY_NJ', 'inSession_NY_NJ_PA', 'inSession_New_England',
       'inSession_New_Jersey', 'inSession_Nothwest', 'INSESSION_PLANES',
       'inSession_SoCal', 'inSession_Southwest', 'SUNSET_WDW',
       'MKEMHMORN', 'MKEMHMYEST', 'MKEMHMTOM', 'MKEMHEVE', 'MKHOURSEMH',
       'MKHOURSEMHYEST', 'MKHOURSEMHTOM', 'MKEMHEYEST', 'MKEMHETOM',
        'MKOPEN', 'MKCLOSE', 'MKHOURS', 'MKEMHOPEN', 'MKEMHCLOSE',
       'MKOPENYEST', 'MKCLOSEYEST', 'MKHOURSYEST', 'MKOPENTOM',
       'MKCLOSETOM', 'MKHOURSTOM', 'MKDAYSBEFORENONEVENT',
       'MKDAYSSINCENONEVENT', 'MKEVENTSTREAK', 'MKEVENTSTREAK_F',
       'WDWMINTEMP_mean', 'WEATHER_WDWHIGH',
       'WEATHER_WDWLOW', 'WEATHER_WDWPRECIP', 'CapacityLost_MK',
       'CapacityLostWGT_MK']].copy()
mk_metadata.to_csv('../metadata/mk_metadata.csv', index = False)

# %%
e_metadata  = disney[['DATE', 'DAYOFWEEK', 'DAYOFYEAR',
       'WEEKOFYEAR', 'MONTHOFYEAR', 'YEAR', 'HOLIDAYPX',
       'HOLIDAYM', 'HOLIDAY',
       'WDWevent', 'WDWrace', 'WDWSEASON', 'WDWMAXTEMP',
       'WDWMINTEMP', 'WDWMEANTEMP', 
       'EPevent',  'inSession', 'inSession_Enrollment', 'inSession_wdw',
       'inSession_sqrt_WDW','inSession_DC', 'inSession_Central_FL',
       'inSession_Drive1_FL', 'inSession_Drive2_FL', 'inSession_Drive_CA',
       'inSession_Florida', 'inSession_Mardi_Gras', 'inSession_Midwest',
       'inSession_NY_NJ', 'inSession_NY_NJ_PA', 'inSession_New_England',
       'inSession_New_Jersey', 'inSession_Nothwest', 'INSESSION_PLANES',
       'inSession_SoCal', 'inSession_Southwest', 'SUNSET_WDW',
       'EPEMHMORN', 'EPEMHMYEST', 'EPEMHMTOM', 'EPEMHEVE', 'EPEMHEYEST',
       'EPEMHETOM', 'EPHOURSEMH', 'EPHOURSEMHYEST', 'EPHOURSEMHTOM',
        'EPOPEN', 'EPCLOSE', 'EPHOURS',
       'EPEMHOPEN', 'EPEMHCLOSE', 'EPOPENYEST', 'EPCLOSEYEST',
       'EPHOURSYEST', 'EPOPENTOM', 'EPCLOSETOM', 'EPHOURSTOM',
       'WDWMINTEMP_mean', 'WEATHER_WDWHIGH',
       'WEATHER_WDWLOW', 'WEATHER_WDWPRECIP', 'CapacityLost_MK',
       'CapacityLost_EP', 'CapacityLostWGT_EP']].copy()
e_metadata.to_csv('../metadata/e_metadata.csv', index = False)

# %%
hs_metadata  = disney[['DATE',  'DAYOFWEEK', 'DAYOFYEAR',
       'WEEKOFYEAR', 'MONTHOFYEAR', 'YEAR', 'HOLIDAYPX',
       'HOLIDAYM', 'HOLIDAY', 
       'WDWevent', 'WDWrace', 'WDWSEASON', 'WDWMAXTEMP',
       'WDWMINTEMP', 'WDWMEANTEMP', 'HSevent',
       'inSession', 'inSession_Enrollment', 'inSession_wdw',
       'inSession_sqrt_WDW', 'inSession_California', 'inSession_DC', 'inSession_Central_FL',
       'inSession_Drive1_FL', 'inSession_Drive2_FL', 'inSession_Drive_CA',
       'inSession_Florida', 'inSession_Mardi_Gras', 'inSession_Midwest',
       'inSession_NY_NJ', 'inSession_NY_NJ_PA', 'inSession_New_England',
       'inSession_New_Jersey', 'inSession_Nothwest', 'INSESSION_PLANES',
       'inSession_SoCal', 'inSession_Southwest', 'SUNSET_WDW',
       'HSEMHMORN', 'HSEMHMYEST', 'HSEMHMTOM', 'HSEMHEVE', 'HSEMHEYEST',
       'HSEMHETOM', 'HSHOURSEMH', 'HSHOURSEMHYEST', 'HSHOURSEMHTOM',
       'HSOPEN', 'HSCLOSE', 'HSHOURS', 'HSEMHOPEN', 'HSEMHCLOSE', 'HSOPENYEST',
       'HSCLOSEYEST', 'HSHOURSYEST', 'HSOPENTOM', 'HSCLOSETOM',
       'HSHOURSTOM', 'WDWMINTEMP_mean', 'WEATHER_WDWHIGH',
       'WEATHER_WDWLOW', 'WEATHER_WDWPRECIP', 'CapacityLost_HS','CapacityLostWGT_HS']].copy()
hs_metadata.to_csv('../metadata/hs_metadata.csv', index = False)

# %%
ak_metadata = disney[['DATE', 'DAYOFWEEK', 'DAYOFYEAR',
       'WEEKOFYEAR', 'MONTHOFYEAR', 'YEAR', 'HOLIDAYPX',
       'HOLIDAYM', 'HOLIDAY', 
       'WDWevent', 'WDWrace', 'WDWSEASON', 'WDWMAXTEMP',
       'WDWMINTEMP', 'WDWMEANTEMP', 'AKevent',
       'inSession', 'inSession_Enrollment', 'inSession_wdw',
       'inSession_sqrt_WDW', 'inSession_California', 'inSession_DC', 'inSession_Central_FL',
       'inSession_Drive1_FL', 'inSession_Drive2_FL', 'inSession_Drive_CA',
       'inSession_Florida', 'inSession_Mardi_Gras', 'inSession_Midwest',
       'inSession_NY_NJ', 'inSession_NY_NJ_PA', 'inSession_New_England',
       'inSession_New_Jersey', 'inSession_Nothwest', 'INSESSION_PLANES',
       'inSession_SoCal', 'inSession_Southwest', 'SUNSET_WDW',
       'AKEMHMORN', 'AKEMHMYEST', 'AKEMHMTOM', 'AKEMHEVE', 'AKEMHEYEST',
       'AKEMHETOM', 'AKHOURSEMH', 'AKHOURSEMHYEST', 'AKHOURSEMHTOM',
       'AKOPEN', 'AKCLOSE', 'AKHOURS', 'AKEMHOPEN',
       'AKEMHCLOSE', 'AKOPENYEST', 'AKCLOSEYEST', 'AKHOURSYEST',
       'AKOPENTOM', 'AKCLOSETOM', 'AKHOURSTOM', 'MKDAYSBEFORENONEVENT',
       'WDWMINTEMP_mean', 'WEATHER_WDWHIGH',
       'WEATHER_WDWLOW', 'WEATHER_WDWPRECIP', 'CapacityLost_AK',
       'CapacityLostWGT_AK']].copy()
ak_metadata.to_csv('../metadata/ak_metadata.csv', index = False)

# %%
disney_metadata = disney[['DATE',  'DAYOFWEEK', 'DAYOFYEAR',
       'WEEKOFYEAR', 'MONTHOFYEAR', 'YEAR', 'HOLIDAYPX',
       'HOLIDAYM', 'HOLIDAY', 
       'WDWevent', 'WDWrace', 'WDWSEASON', 'WDWMAXTEMP',
       'WDWMINTEMP', 'WDWMEANTEMP', 'MKevent',
       'EPevent', 'HSevent', 'AKevent',
       'inSession', 'inSession_Enrollment', 'inSession_wdw',
       'inSession_dlr', 'inSession_sqrt_WDW', 'inSession_sqrt_DLR',
       'inSession_California', 'inSession_DC', 'inSession_Central_FL',
       'inSession_Drive1_FL', 'inSession_Drive2_FL', 'inSession_Drive_CA',
       'inSession_Florida', 'inSession_Mardi_Gras', 'inSession_Midwest',
       'inSession_NY_NJ', 'inSession_NY_NJ_PA', 'inSession_New_England',
       'inSession_New_Jersey', 'inSession_Nothwest', 'INSESSION_PLANES',
       'inSession_SoCal', 'inSession_Southwest', 'SUNSET_WDW',
       'MKEMHMORN', 'MKEMHMYEST', 'MKEMHMTOM', 'MKEMHEVE', 'MKHOURSEMH',
       'MKHOURSEMHYEST', 'MKHOURSEMHTOM', 'MKEMHEYEST', 'MKEMHETOM',
       'EPEMHMORN', 'EPEMHMYEST', 'EPEMHMTOM', 'EPEMHEVE', 'EPEMHEYEST',
       'EPEMHETOM', 'EPHOURSEMH', 'EPHOURSEMHYEST', 'EPHOURSEMHTOM',
       'HSEMHMORN', 'HSEMHMYEST', 'HSEMHMTOM', 'HSEMHEVE', 'HSEMHEYEST',
       'HSEMHETOM', 'HSHOURSEMH', 'HSHOURSEMHYEST', 'HSHOURSEMHTOM',
       'AKEMHMORN', 'AKEMHMYEST', 'AKEMHMTOM', 'AKEMHEVE', 'AKEMHEYEST',
       'AKEMHETOM', 'AKHOURSEMH', 'AKHOURSEMHYEST', 'AKHOURSEMHTOM',
       'MKOPEN', 'MKCLOSE', 'MKHOURS', 'MKEMHOPEN', 'MKEMHCLOSE',
       'MKOPENYEST', 'MKCLOSEYEST', 'MKHOURSYEST', 'MKOPENTOM',
       'MKCLOSETOM', 'MKHOURSTOM', 'EPOPEN', 'EPCLOSE', 'EPHOURS',
       'EPEMHOPEN', 'EPEMHCLOSE', 'EPOPENYEST', 'EPCLOSEYEST',
       'EPHOURSYEST', 'EPOPENTOM', 'EPCLOSETOM', 'EPHOURSTOM', 'HSOPEN',
       'HSCLOSE', 'HSHOURS', 'HSEMHOPEN', 'HSEMHCLOSE', 'HSOPENYEST',
       'HSCLOSEYEST', 'HSHOURSYEST', 'HSOPENTOM', 'HSCLOSETOM',
       'HSHOURSTOM', 'AKOPEN', 'AKCLOSE', 'AKHOURS', 'AKEMHOPEN',
       'AKEMHCLOSE', 'AKOPENYEST', 'AKCLOSEYEST', 'AKHOURSYEST',
       'AKOPENTOM', 'AKCLOSETOM', 'AKHOURSTOM', 'MKDAYSBEFORENONEVENT',
       'MKDAYSSINCENONEVENT', 'MKEVENTSTREAK', 'MKEVENTSTREAK_F',
        'WDWMINTEMP_mean', 'WEATHER_WDWHIGH',
       'WEATHER_WDWLOW', 'WEATHER_WDWPRECIP', 'CapacityLost_MK',
       'CapacityLost_EP', 'CapacityLost_HS', 'CapacityLost_AK',
       'CapacityLostWGT_MK', 'CapacityLostWGT_EP', 'CapacityLostWGT_HS',
       'CapacityLostWGT_AK', 'EP09CAPACITY', 'HS20CAPACITY', 'MKPRDDAY',
       'MKPRDDT1', 'MKPRDDT2', 'MKPRDDN', 'MKPRDNGT', 'MKPRDNT1',
       'MKPRDNT2', 'MKPRDNN', 'MKFIREWK', 'MKFIRET1', 'MKFIRET2',
       'MKFIREN', 'EPFIREWK', 'EPFIRET1', 'EPFIRET2', 'EPFIREN',
       'HSPRDDAY', 'HSPRDDT1', 'HSPRDDN', 'HSFIREWK', 'HSFIRET1',
       'HSFIRET2', 'HSFIREN', 'HSSHWNGT', 'HSSHWNT1', 'HSSHWNT2',
       'HSSHWNN', 'HSFIREWKS', 'AKPRDDAY', 'AKPRDDT1', 'AKPRDDT2',
       'AKPRDDN', 'AKFIREN', 'AKSHWNGT', 'AKSHWNT1', 'AKSHWNT2',
       'AKSHWNN']].copy()
disney_metadata.to_csv('../metadata/disney_metadata.csv', index = False)

# %%
other = ['DATE,Time,Wait_Time,DAYOFWEEK,DAYOFYEAR,WEEKOFYEAR,MONTHOFYEAR,HOLIDAYPX,HOLIDAYM,HOLIDAY,'
         'WDWevent,WDWrace,WDWMEANTEMP,AKevent,AKEMHMORN,AKEMHMYEST,AKEMHMTOM,AKEMHEVE,AKEMHEYEST,'
         'AKEMHETOM,AKHOURSEMH,AKHOURSEMHYEST,AKHOURSEMHTOM,AKHOURS,WEATHER_WDWPRECIP,'
         'CapacityLost_AK,CapacityLostWGT_AK,AKPRDDAY']

# %%
mk_metadata
# Out:
#            DATE  DAYOFWEEK  DAYOFYEAR  WEEKOFYEAR  MONTHOFYEAR  YEAR  HOLIDAYPX  HOLIDAYM  \
# 1096 2015-01-01          5          0           0            1  2015          0         5
# 1097 2015-01-02          6          1           0            1  2015          2         5
# 1098 2015-01-03          7          2           0            1  2015          3         0
# 1099 2015-01-04          1          3           1            1  2015          4         0
# 1100 2015-01-05          2          4           1            1  2015          5         0
# ...         ...        ...        ...         ...          ...   ...        ...       ...
# 3221 2019-12-26          5        359          51           12  2019          2         5
# 3222 2019-12-27          6        360          51           12  2019          3         5
# 3223 2019-12-28          7        361          51           12  2019          4         5
# ...

# %%
pd.crosstab(disney.YEAR, disney.SEASON)
# Out:
# SEASON  CHRISTMAS  CHRISTMAS PEAK  COLUMBUS DAY  EASTER  FALL  HALLOWEEN  JERSEY WEEK  JULY 4TH  \
# YEAR
# 2015           17               6             4      19    42          3           10         5
# 2016           17               6             4      19    40          6           10         5
# 2017           17               6             4      19    41          6           10         5
# 2018           17               6             4      19    42          6           10         5
# 2019           17               5             4      19    47          5           10         5
#
# SEASON  MARDI GRAS  MARTIN LUTHER KING JUNIOR DAY  MEMORIAL DAY  PRESIDENTS WEEK  SEPTEMBER LOW  \
# YEAR
# 2015             0                              9             4               11             28
# 2016             4                              9             4               11             28
# ...

# %%
disney['WDWSEASON']
# Out:
# 1096    CHRISTMAS PEAK
# 1097         CHRISTMAS
# 1098         CHRISTMAS
# 1099         CHRISTMAS
# 1100         CHRISTMAS
#              ...
# 3221    CHRISTMAS PEAK
# 3222    CHRISTMAS PEAK
# 3223    CHRISTMAS PEAK
# 3224    CHRISTMAS PEAK
# 3225    CHRISTMAS PEAK
# Name: WDWSEASON, Length: 1823, dtype: object
