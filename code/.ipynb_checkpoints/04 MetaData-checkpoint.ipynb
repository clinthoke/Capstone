# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 50)
pd.set_option('display.width', 100)

# %%
disney = pd.read_csv("metadata.csv")
disney.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3226 entries, 0 to 3225
# Columns: 190 entries, DATE to AKSHWNN
# dtypes: float64(34), int64(61), object(95)
# memory usage: 4.7+ MB

# %%
disney.shape
# Out:
# (3226, 190)

# %%
disney.T.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 190 entries, DATE to AKSHWNN
# Columns: 3226 entries, 0 to 3225
# dtypes: object(3226)
# memory usage: 4.7+ MB

# %%
disney.T
# Out:
#                                                       0                                    1     \
# DATE                                            01/01/2012                           01/02/2012
# WDW_TICKET_SEASON                                      NaN                                  NaN
# DAYOFWEEK                                                1                                    2
# DAYOFYEAR                                                0                                    1
# WEEKOFYEAR                                               1                                    1
# MONTHOFYEAR                                              1                                    1
# YEAR                                                  2012                                 2012
# SEASON                                      CHRISTMAS PEAK                            CHRISTMAS
# HOLIDAYPX                                                0                                    2
# ...

# %%
disney.tail(50)
# Out:
#             DATE WDW_TICKET_SEASON  DAYOFWEEK  DAYOFYEAR  WEEKOFYEAR  MONTHOFYEAR  YEAR  \
# 3176  11/11/2019               NaN          2        314          45           11  2019
# 3177  11/12/2019               NaN          3        315          45           11  2019
# 3178  11/13/2019               NaN          4        316          45           11  2019
# 3179  11/14/2019               NaN          5        317          45           11  2019
# 3180  11/15/2019               NaN          6        318          45           11  2019
# 3181  11/16/2019               NaN          7        319          45           11  2019
# 3182  11/17/2019               NaN          1        320          46           11  2019
# 3183  11/18/2019               NaN          2        321          46           11  2019
# 3184  11/19/2019               NaN          3        322          46           11  2019
# 3185  11/20/2019               NaN          4        323          46           11  2019
# ...

# %%
# pd.crosstab(index=disney['index'], columns=disney['WDW_TICKET_SEASON'])

# %%
pd.crosstab(disney.YEAR, disney.WDW_TICKET_SEASON)
# Out:
# WDW_TICKET_SEASON  peak  regular  value
# YEAR
# 2016                 99      165     44
# 2017                238      161     85
# 2018                166      300     85
# 2019                 38       90     52

# %%
pd.crosstab(disney.YEAR, disney.WDWTICKETSEASON)
# Out:
# WDWTICKETSEASON  peak  regular  value
# YEAR
# 2016               99      165     44
# 2017              238      161     85
# 2018              166      300     85
# 2019               93      192     79

# %%
disney["WDW_TICKET_SEASON"].value_counts()
# Out:
# regular    716
# peak       541
# value      266
# Name: WDW_TICKET_SEASON, dtype: int64

# %%
disney["WDWTICKETSEASON"].value_counts()
# Out:
# regular    818
# peak       596
# value      293
# Name: WDWTICKETSEASON, dtype: int64
