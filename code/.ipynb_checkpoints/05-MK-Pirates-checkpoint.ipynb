# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Import Magic Kingdom attractions
mka = pd.read_csv("../attractions/attractions_mk.csv")
mka.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31039 entries, 0 to 31038
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              31039 non-null  object
#  1   seven_dwarfs_train    31039 non-null  object
#  2   pirates_of_caribbean  31039 non-null  object
#  3   splash_mountain       31039 non-null  object
# dtypes: object(4)
# memory usage: 970.1+ KB

# %%
# Added DATE column to mk from the datetime column, using it to concat dataframes
mka['DATE'] = pd.to_datetime(mka['datetime']).dt.date
mka['DATE'] = pd.to_datetime(mka["DATE"])
print(mka.info())
mka.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31039 entries, 0 to 31038
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              31039 non-null  object
#  1   seven_dwarfs_train    31039 non-null  object
#  2   pirates_of_caribbean  31039 non-null  object
#  3   splash_mountain       31039 non-null  object
#  4   DATE                  31039 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(4)
# memory usage: 1.2+ MB
# None
#               datetime seven_dwarfs_train pirates_of_caribbean  \
# 0  2015-01-01 07:00:00               45.0                   na
# 1  2015-01-01 08:00:00               78.0                   na
#
#   splash_mountain       DATE
# 0             5.0 2015-01-01
# 1             5.0 2015-01-01

# %%
# Import Metadata
md = pd.read_csv("../metadata/mk_metadata.csv")
md.head(2)
# Out:
#          DATE  DAYOFWEEK  DAYOFYEAR  WEEKOFYEAR  MONTHOFYEAR  YEAR  HOLIDAYPX  \
# 0  2015-01-01          5          0           0            1  2015          0
# 1  2015-01-02          6          1           0            1  2015          2
#
#    HOLIDAYM  HOLIDAY  WDWevent  ...  MKDAYSBEFORENONEVENT MKDAYSSINCENONEVENT  \
# 0         5        1         0  ...                   1.0                   1
# 1         5        0         0  ...                   1.0                   1
#
#    MKEVENTSTREAK  MKEVENTSTREAK_F  WDWMINTEMP_mean  WEATHER_WDWHIGH  \
# 0              0                0        53.375714             70.3
# 1              0                0        53.750714             70.3
#
#   WEATHER_WDWLOW WEATHER_WDWPRECIP CapacityLost_MK CapacityLostWGT_MK
# 0           50.2              0.12          616246           53904354
# 1           50.0              0.12          616246           53904354
#
# [2 rows x 66 columns]

# %%
# Convert DATE column to datetime
md['DATE'] = pd.to_datetime(md["DATE"])
md.head(2)
# Out:
#         DATE  DAYOFWEEK  DAYOFYEAR  WEEKOFYEAR  MONTHOFYEAR  YEAR  HOLIDAYPX  \
# 0 2015-01-01          5          0           0            1  2015          0
# 1 2015-01-02          6          1           0            1  2015          2
#
#    HOLIDAYM  HOLIDAY  WDWevent  ...  MKDAYSBEFORENONEVENT MKDAYSSINCENONEVENT  \
# 0         5        1         0  ...                   1.0                   1
# 1         5        0         0  ...                   1.0                   1
#
#    MKEVENTSTREAK  MKEVENTSTREAK_F  WDWMINTEMP_mean  WEATHER_WDWHIGH  \
# 0              0                0        53.375714             70.3
# 1              0                0        53.750714             70.3
#
#   WEATHER_WDWLOW WEATHER_WDWPRECIP CapacityLost_MK CapacityLostWGT_MK
# 0           50.2              0.12          616246           53904354
# 1           50.0              0.12          616246           53904354
#
# [2 rows x 66 columns]

# %%
# Merge mka and md dataframes
mk = pd.merge(mka, md, how='outer', on='DATE')
# Dropped unneeded Date column
mk.drop('DATE', axis = 1,  inplace = True)
# Set datetime to the Index and sorted by it
mk.set_index('datetime', inplace=True)
mk.sort_index(inplace=True)
mk.head(2)
# Out:
#                     seven_dwarfs_train pirates_of_caribbean splash_mountain  \
# datetime
# 2015-01-01 07:00:00               45.0                   na             5.0
# 2015-01-01 08:00:00               78.0                   na             5.0
#
#                      DAYOFWEEK  DAYOFYEAR  WEEKOFYEAR  MONTHOFYEAR    YEAR  \
# datetime
# 2015-01-01 07:00:00        5.0        0.0         0.0          1.0  2015.0
# 2015-01-01 08:00:00        5.0        0.0         0.0          1.0  2015.0
#
#                      HOLIDAYPX  HOLIDAYM  ...  MKDAYSBEFORENONEVENT  \
# datetime                                  ...
# 2015-01-01 07:00:00        0.0       5.0  ...                   1.0
# 2015-01-01 08:00:00        0.0       5.0  ...                   1.0
#
#                      MKDAYSSINCENONEVENT  MKEVENTSTREAK MKEVENTSTREAK_F  \
# datetime
# 2015-01-01 07:00:00                  1.0            0.0             0.0
# 2015-01-01 08:00:00                  1.0            0.0             0.0
#
#                      WDWMINTEMP_mean  WEATHER_WDWHIGH  WEATHER_WDWLOW  \
# datetime
# 2015-01-01 07:00:00        53.375714             70.3            50.2
# 2015-01-01 08:00:00        53.375714             70.3            50.2
#
#                      WEATHER_WDWPRECIP CapacityLost_MK CapacityLostWGT_MK
# datetime
# 2015-01-01 07:00:00               0.12        616246.0         53904354.0
# 2015-01-01 08:00:00               0.12        616246.0         53904354.0
#
# [2 rows x 68 columns]

# %%
for col in ['MKOPEN', 'MKCLOSE',  'MKEMHOPEN', 'MKEMHCLOSE',
       'MKOPENYEST', 'MKCLOSEYEST', 'MKOPENTOM',
       'MKCLOSETOM','SUNSET_WDW']:
    mk[col] = np.where(mk[col] == "24:00",'23:59' ,mk[col])
    mk[col] = np.where(mk[col] == "27:00",'23:59' ,mk[col])
    mk[col] = np.where(mk[col] == "26:00",'23:59' ,mk[col])
    mk[col] = np.where(mk[col] == "25:00",'23:59' ,mk[col])
    mk[col] = np.where(mk[col] == "23:55",'23:59' ,mk[col])
    mk[col] = np.where(mk[col] == "29:59",'23:59' ,mk[col])
    mk[col] = np.where(mk[col] == "30:00",'23:59' ,mk[col])

# %%
for col in ['MKOPEN', 'MKCLOSE',  'MKEMHOPEN', 'MKEMHCLOSE',
       'MKOPENYEST', 'MKCLOSEYEST', 'MKOPENTOM',
       'MKCLOSETOM','SUNSET_WDW']:
    mk[col] = mk[col].str.replace(":","")

# %%
mk.fillna(0, inplace=True)
mk.isnull().sum()
# Out:
# seven_dwarfs_train      0
# pirates_of_caribbean    0
# splash_mountain         0
# DAYOFWEEK               0
# DAYOFYEAR               0
#                        ..
# WEATHER_WDWHIGH         0
# WEATHER_WDWLOW          0
# WEATHER_WDWPRECIP       0
# CapacityLost_MK         0
# CapacityLostWGT_MK      0
# Length: 68, dtype: int64

# %%
for col in ['MKOPEN', 'MKCLOSE',  'MKEMHOPEN', 'MKEMHCLOSE',
       'MKOPENYEST', 'MKCLOSEYEST', 'MKOPENTOM',
       'MKCLOSETOM','SUNSET_WDW']:
    mk[col] = mk[col].astype(int)

# %%
for col in ['inSession', 'inSession_Enrollment', 'inSession_wdw',
       'inSession_sqrt_WDW', 'inSession_DC', 'inSession_Central_FL',
       'inSession_Drive1_FL', 'inSession_Drive2_FL',
       'inSession_Florida', 'inSession_Mardi_Gras', 'inSession_Midwest',
       'inSession_NY_NJ', 'inSession_NY_NJ_PA', 'inSession_New_England',
       'inSession_New_Jersey', 'inSession_Nothwest', 'INSESSION_PLANES',
       'inSession_SoCal', 'inSession_Southwest']:
    mk[col] = mk[col].str.replace(r'%', r'').astype('float')/-100

# %%
for col in ['seven_dwarfs_train', "pirates_of_caribbean", "splash_mountain"]:
    mk[col] = pd.to_numeric(mk[col],errors='coerce')
mk.fillna(0, inplace=True)

# %%
# Dummified the WDWSEASON column
mk = pd.get_dummies(mk,columns = ['WDWSEASON'])

# %%
# Created new column for hour as a feature
mk['hour'] = mk.index
mk['hour'] = mk.hour.str[11:13]
mk['hour'] = pd.to_numeric(mk['hour'])*100
mk.tail(5)
# Out:
#                      seven_dwarfs_train  pirates_of_caribbean  \
# datetime
# 2019-12-30 21:00:00               113.0                  25.0
# 2019-12-30 22:00:00                78.0                  27.0
# 2019-12-30 23:00:00                50.0                  16.0
# 2019-12-31 00:00:00                48.0                   8.0
# 2019-12-31 01:00:00                41.0                   5.0
#
#                      splash_mountain  DAYOFWEEK  DAYOFYEAR  WEEKOFYEAR  \
# datetime
# 2019-12-30 21:00:00             42.0        2.0      363.0        52.0
# 2019-12-30 22:00:00             33.0        2.0      363.0        52.0
# 2019-12-30 23:00:00             14.0        2.0      363.0        52.0
# 2019-12-31 00:00:00              0.0        0.0        0.0         0.0
# 2019-12-31 01:00:00              0.0        0.0        0.0         0.0
#
#                      MONTHOFYEAR    YEAR  HOLIDAYPX  HOLIDAYM  ...  \
# datetime                                                       ...
# 2019-12-30 21:00:00         12.0  2019.0        2.0       5.0  ...
# 2019-12-30 22:00:00         12.0  2019.0        2.0       5.0  ...
# 2019-12-30 23:00:00         12.0  2019.0        2.0       5.0  ...
# 2019-12-31 00:00:00          0.0     0.0        0.0       0.0  ...
# 2019-12-31 01:00:00          0.0     0.0        0.0       0.0  ...
#
#                      WDWSEASON_MARDI GRAS  \
# datetime
# 2019-12-30 21:00:00                     0
# 2019-12-30 22:00:00                     0
# 2019-12-30 23:00:00                     0
# 2019-12-31 00:00:00                     0
# 2019-12-31 01:00:00                     0
#
#                      WDWSEASON_MARTIN LUTHER KING JUNIOR DAY  \
# datetime
# 2019-12-30 21:00:00                                        0
# 2019-12-30 22:00:00                                        0
# 2019-12-30 23:00:00                                        0
# 2019-12-31 00:00:00                                        0
# 2019-12-31 01:00:00                                        0
#
#                      WDWSEASON_MEMORIAL DAY  WDWSEASON_PRESIDENTS WEEK  \
# datetime
# 2019-12-30 21:00:00                       0                          0
# 2019-12-30 22:00:00                       0                          0
# 2019-12-30 23:00:00                       0                          0
# 2019-12-31 00:00:00                       0                          0
# 2019-12-31 01:00:00                       0                          0
#
#                      WDWSEASON_SEPTEMBER LOW  WDWSEASON_SPRING  \
# datetime
# 2019-12-30 21:00:00                        0                 0
# 2019-12-30 22:00:00                        0                 0
# 2019-12-30 23:00:00                        0                 0
# 2019-12-31 00:00:00                        0                 0
# 2019-12-31 01:00:00                        0                 0
#
#                      WDWSEASON_SUMMER BREAK  WDWSEASON_THANKSGIVING  \
# datetime
# 2019-12-30 21:00:00                       0                       0
# 2019-12-30 22:00:00                       0                       0
# 2019-12-30 23:00:00                       0                       0
# 2019-12-31 00:00:00                       0                       0
# 2019-12-31 01:00:00                       0                       0
#
#                      WDWSEASON_WINTER  hour
# datetime
# 2019-12-30 21:00:00                 0  2100
# 2019-12-30 22:00:00                 0  2200
# 2019-12-30 23:00:00                 0  2300
# 2019-12-31 00:00:00                 0     0
# 2019-12-31 01:00:00                 0   100
#
# [5 rows x 86 columns]

# %%
mk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31039 entries, 2015-01-01 07:00:00 to 2019-12-31 01:00:00
# Data columns (total 86 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   seven_dwarfs_train                       31039 non-null  float64
#  1   pirates_of_caribbean                     31039 non-null  float64
#  2   splash_mountain                          31039 non-null  float64
#  3   DAYOFWEEK                                31039 non-null  float64
#  4   DAYOFYEAR                                31039 non-null  float64
#  5   WEEKOFYEAR                               31039 non-null  float64
#  6   MONTHOFYEAR                              31039 non-null  float64
#  7   YEAR                                     31039 non-null  float64
#  8   HOLIDAYPX                                31039 non-null  float64
#  9   HOLIDAYM                                 31039 non-null  float64
#  10  HOLIDAY                                  31039 non-null  float64
#  11  WDWevent                                 31039 non-null  float64
#  12  WDWrace                                  31039 non-null  float64
#  13  WDWMAXTEMP                               31039 non-null  float64
#  14  WDWMINTEMP                               31039 non-null  float64
#  15  WDWMEANTEMP                              31039 non-null  float64
#  16  MKevent                                  31039 non-null  float64
#  17  inSession                                31039 non-null  float64
#  18  inSession_Enrollment                     31039 non-null  float64
#  19  inSession_wdw                            31039 non-null  float64
#  20  inSession_sqrt_WDW                       31039 non-null  float64
#  21  inSession_DC                             31039 non-null  float64
#  22  inSession_Central_FL                     31039 non-null  float64
#  23  inSession_Drive1_FL                      31039 non-null  float64
#  24  inSession_Drive2_FL                      31039 non-null  float64
#  25  inSession_Florida                        31039 non-null  float64
#  26  inSession_Mardi_Gras                     31039 non-null  float64
#  27  inSession_Midwest                        31039 non-null  float64
#  28  inSession_NY_NJ                          31039 non-null  float64
#  29  inSession_NY_NJ_PA                       31039 non-null  float64
#  30  inSession_New_England                    31039 non-null  float64
#  31  inSession_New_Jersey                     31039 non-null  float64
#  32  inSession_Nothwest                       31039 non-null  float64
#  33  INSESSION_PLANES                         31039 non-null  float64
#  34  inSession_SoCal                          31039 non-null  float64
#  35  inSession_Southwest                      31039 non-null  float64
#  36  SUNSET_WDW                               31039 non-null  int64
#  37  MKEMHMORN                                31039 non-null  float64
#  38  MKEMHMYEST                               31039 non-null  float64
#  39  MKEMHMTOM                                31039 non-null  float64
#  40  MKEMHEVE                                 31039 non-null  float64
#  41  MKHOURSEMH                               31039 non-null  float64
#  42  MKHOURSEMHYEST                           31039 non-null  float64
#  43  MKHOURSEMHTOM                            31039 non-null  float64
#  44  MKEMHEYEST                               31039 non-null  float64
#  45  MKEMHETOM                                31039 non-null  float64
#  46  MKOPEN                                   31039 non-null  int64
#  47  MKCLOSE                                  31039 non-null  int64
#  48  MKHOURS                                  31039 non-null  float64
#  49  MKEMHOPEN                                31039 non-null  int64
#  50  MKEMHCLOSE                               31039 non-null  int64
#  51  MKOPENYEST                               31039 non-null  int64
#  52  MKCLOSEYEST                              31039 non-null  int64
#  53  MKHOURSYEST                              31039 non-null  float64
#  54  MKOPENTOM                                31039 non-null  int64
#  55  MKCLOSETOM                               31039 non-null  int64
#  56  MKHOURSTOM                               31039 non-null  float64
#  57  MKDAYSBEFORENONEVENT                     31039 non-null  float64
#  58  MKDAYSSINCENONEVENT                      31039 non-null  float64
#  59  MKEVENTSTREAK                            31039 non-null  float64
#  60  MKEVENTSTREAK_F                          31039 non-null  float64
#  61  WDWMINTEMP_mean                          31039 non-null  float64
#  62  WEATHER_WDWHIGH                          31039 non-null  float64
#  63  WEATHER_WDWLOW                           31039 non-null  float64
#  64  WEATHER_WDWPRECIP                        31039 non-null  float64
#  65  CapacityLost_MK                          31039 non-null  float64
#  66  CapacityLostWGT_MK                       31039 non-null  float64
#  67  WDWSEASON_0                              31039 non-null  uint8
#  68  WDWSEASON_CHRISTMAS                      31039 non-null  uint8
#  69  WDWSEASON_CHRISTMAS PEAK                 31039 non-null  uint8
#  70  WDWSEASON_COLUMBUS DAY                   31039 non-null  uint8
#  71  WDWSEASON_EASTER                         31039 non-null  uint8
#  72  WDWSEASON_FALL                           31039 non-null  uint8
#  73  WDWSEASON_HALLOWEEN                      31039 non-null  uint8
#  74  WDWSEASON_JERSEY WEEK                    31039 non-null  uint8
#  75  WDWSEASON_JULY 4TH                       31039 non-null  uint8
#  76  WDWSEASON_MARDI GRAS                     31039 non-null  uint8
#  77  WDWSEASON_MARTIN LUTHER KING JUNIOR DAY  31039 non-null  uint8
#  78  WDWSEASON_MEMORIAL DAY                   31039 non-null  uint8
#  79  WDWSEASON_PRESIDENTS WEEK                31039 non-null  uint8
#  80  WDWSEASON_SEPTEMBER LOW                  31039 non-null  uint8
#  81  WDWSEASON_SPRING                         31039 non-null  uint8
#  82  WDWSEASON_SUMMER BREAK                   31039 non-null  uint8
#  83  WDWSEASON_THANKSGIVING                   31039 non-null  uint8
#  84  WDWSEASON_WINTER                         31039 non-null  uint8
#  85  hour                                     31039 non-null  int64
# dtypes: float64(58), int64(10), uint8(18)
# memory usage: 16.9+ MB

# %%
mk.to_csv('../metadata/mk.csv', index = False)

# %%
top_corr = mk.corr()
top_corr_features = top_corr.index[abs(top_corr["pirates_of_caribbean"]) > .10]
plt.figure(figsize=(20,20))
g = sns.heatmap(mk[top_corr_features].corr(),annot=True,cmap="magma")

# %%
corr = mk.corr()
plt.figure(figsize = (6,18))
sns.heatmap(corr[['pirates_of_caribbean']].sort_values(by = 'pirates_of_caribbean', ascending = False).head(70),vmin = 0, annot = True)
plt.show()

# %%
import numpy as np
from math import sqrt
from sklearn.datasets import make_classification, make_regression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GRU
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from sklearn.linear_model import LinearRegression
from datetime import date
from sklearn import metrics
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
import statsmodels.api as sm

# %%
from math import sqrt
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, BaggingRegressor
from sklearn.linear_model import Ridge, RidgeCV, LinearRegression, LogisticRegression, Lasso, LassoCV
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.ensemble import BaggingRegressor, BaggingClassifier, RandomForestRegressor, RandomForestClassifier, AdaBoostRegressor, AdaBoostClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.metrics import mean_squared_error
from sklearn.metrics import f1_score
from sklearn import svm

# %%
#
features = ['splash_mountain', 'seven_dwarfs_train', 'inSession',
            'YEAR', 'MKHOURS', 'DAYOFWEEK','HOLIDAYM',
            'WDWSEASON_CHRISTMAS', 'WDWSEASON_CHRISTMAS PEAK', 'MKOPEN',
       'WDWSEASON_COLUMBUS DAY', 'WDWSEASON_EASTER', 'WDWSEASON_FALL',
       'WDWSEASON_HALLOWEEN', 'WDWSEASON_JERSEY WEEK', 'WDWSEASON_JULY 4TH',
       'WDWSEASON_MARDI GRAS', 'WDWSEASON_MARTIN LUTHER KING JUNIOR DAY',
       'WDWSEASON_MEMORIAL DAY', 'WDWSEASON_PRESIDENTS WEEK',
       'WDWSEASON_SEPTEMBER LOW', 'WDWSEASON_SPRING', 'WDWSEASON_SUMMER BREAK',
       'WDWSEASON_THANKSGIVING', 'WDWSEASON_WINTER', 'CapacityLost_MK',
            'CapacityLostWGT_MK', 'hour']
y = mk['pirates_of_caribbean']
X = mk[features]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =.02, random_state=21)
sc = StandardScaler()
sc.fit(X_train)
X_train_sc = sc.transform(X_train)
X_test_sc = sc.transform(X_test)

# %%
# Created my model and started the train test split
linreg = LinearRegression()
linreg.fit(X_train_sc, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
linreg_preds_train = linreg.predict(X_train_sc)
linreg_rms_train = sqrt(mean_squared_error(y_train, linreg_preds_train))
linreg_rms_train
# Out:
# 12.24126236127085

# %%
linreg_preds_test = linreg.predict(X_test_sc)
linreg_rms_test = sqrt(mean_squared_error(y_test, linreg_preds_test))
linreg_rms_test
# Out:
# 11.706840694628907

# %%
11.70
# Out:
# 11.7

# %% [markdown]
# ## KNN

# %%
# Instiantiated KNN and fitted the training
knn = KNeighborsRegressor()
knn.fit(X_train_sc, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform')

# %%
knn_preds_train = knn.predict(X_train_sc)
knn_rms_train = sqrt(mean_squared_error(y_train, knn_preds_train))
knn_rms_train
# Out:
# 7.4475783868312915

# %%
knn_preds_test = knn.predict(X_test_sc)
knn_rms_test = sqrt(mean_squared_error(y_test, knn_preds_test))
knn_rms_test
# Out:
# 8.695407564997575

# %%
8.69
# Out:
# 8.69

# %% [markdown]
# ## Decision Tree Model

# %%
# Instiantiate model and fit
dt = DecisionTreeRegressor()
dt.fit(X_train_sc, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
dt_preds_train = dt.predict(X_train_sc)
dt_rms_train = sqrt(mean_squared_error(y_train, dt_preds_train))
dt_rms_train
# Out:
# 0.0879270603898609

# %%
dt_preds_test = dt.predict(X_test_sc)
dt_rms_test = sqrt(mean_squared_error(y_test, dt_preds_test))
dt_rms_test
# Out:
# 12.07458037131383

# %%
12.07
# Out:
# 12.07

# %% [markdown]
# ## Bagged Decision Tree

# %%
# Instiantiate model and fit
bag = BaggingRegressor()
bag.fit(X_train_sc, y_train)
# Out:
# BaggingRegressor(base_estimator=None, bootstrap=True, bootstrap_features=False,
#                  max_features=1.0, max_samples=1.0, n_estimators=10,
#                  n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                  warm_start=False)

# %%
bag_preds_train = bag.predict(X_train_sc)
bag_rms_train = sqrt(mean_squared_error(y_train, bag_preds_train))
bag_rms_train
# Out:
# 3.8203940987546

# %%
bag_preds_test = bag.predict(X_test_sc)
bag_rms_test = sqrt(mean_squared_error(y_test, bag_preds_test))
bag_rms_test
# Out:
# 9.004531870280573

# %%
8.68
# Out:
# 8.68

# %% [markdown]
# ## Random Forests

# %%
# Instiantiate model and fit
rf = RandomForestRegressor()
rf.fit(X_train_sc, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
rf_preds_train = rf.predict(X_train_sc)
rf_rms_train = sqrt(mean_squared_error(y_train, rf_preds_train))
rf_rms_train
# Out:
# 3.1897654185207256

# %%
rf_preds_test = rf.predict(X_test_sc)
rf_rms_test = sqrt(mean_squared_error(y_test, rf_preds_test))
rf_rms_test
# Out:
# 8.74294772251332

# %%
8.74
# Out:
# 8.48

# %% [markdown]
# ## ADA boost

# %%
# Instiantiate model and fit
ada = AdaBoostRegressor()
ada.fit(X_train_sc, y_train)
# Out:
# AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#                   n_estimators=50, random_state=None)

# %%
ada_preds_train = ada.predict(X_train_sc)
ada_rms_train = sqrt(mean_squared_error(y_train, ada_preds_train))
ada_rms_train
# Out:
# 13.398282569535079

# %%
ada_preds_test = ada.predict(X_test_sc)
ada_rms_test = sqrt(mean_squared_error(y_test, ada_preds_test))
ada_rms_test
# Out:
# 13.464653672121786

# %% [markdown]
# ## SVM

# %%
# Instiantiate model and fit
svr = svm.SVR()
svr.fit(X_train_sc, y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
svr_preds_train = svr.predict(X_train_sc)
svr_rms_train = sqrt(mean_squared_error(y_train, svr_preds_train))
svr_rms_train
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-86-2eec1cfe157f> in <module>
# ----> 1 svr_preds_train = svr.predict(X_train_sc)
#       2 svr_rms_train = sqrt(mean_squared_error(y_train, svr_preds_train))
#       3 svr_rms_train
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py in predict(self, X)
#     315         X = self._validate_for_predict(X)
#     316         predict = self._sparse_predict if self._sparse else self._dense_predict
# --> 317         return predict(X)
#     318
#     319     def _dense_predict(self, X):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py in _dense_predict(self, X)
#     337             self.probA_, self.probB_, svm_type=svm_type, kernel=kernel,
#     338             degree=self.degree, coef0=self.coef0, gamma=self._gamma,
# --> 339             cache_size=self.cache_size)
#     340
#     341     def _sparse_predict(self, X):
#
# KeyboardInterrupt:

# %%
svr_preds_test = svr.predict(X_test_sc)
svr_rms_test = sqrt(mean_squared_error(y_test, svr_preds_test))
svr_rms_test

# %%
11.30
# Out:
# 11.3
