# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
slinky_dog = pd.read_csv("../cleaned_data/slinky_dog.csv")
slinky_dog.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70602 entries, 0 to 70601
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      70602 non-null  object
#  1   datetime  70602 non-null  object
#  2   SPOSTMIN  70602 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 1.6+ MB

# %%
slinky_dog
# Out:
#              date             datetime  SPOSTMIN
# 0      2018-06-30  2018-06-30 07:44:06     270.0
# 1      2018-06-30  2018-06-30 07:51:06     270.0
# 2      2018-06-30  2018-06-30 07:58:07     270.0
# 3      2018-06-30  2018-06-30 08:02:08     270.0
# 4      2018-06-30  2018-06-30 08:09:06     270.0
# ...           ...                  ...       ...
# 70597  2020-03-13  2020-03-13 19:51:01      55.0
# 70598  2020-03-13  2020-03-13 19:58:02      40.0
# 70599  2020-03-13  2020-03-13 20:09:02      40.0
# 70600  2020-03-13  2020-03-13 20:16:02      40.0
# 70601  2020-03-13  2020-03-13 20:23:02      35.0
#
# [70602 rows x 3 columns]

# %%
pd.crosstab(slinky_dog.date, slinky_dog.SPOSTMIN)
# Out:
# SPOSTMIN    5.0    10.0   15.0   20.0   25.0   30.0   35.0   40.0   45.0   \
# date
# 2018-06-30      0      0      0      0      0      0      0      0      0
# 2018-07-01      2      0      0      0      0      0      0      0      0
# 2018-07-02      1      0      0      0      0      0      0      0      0
# 2018-07-03      0      0      0      0      0      1      0      0      5
# 2018-07-04      0      0      0      0     11      4      3      2      6
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2020-03-09      0      0      0      0      0      0      0      0      2
# 2020-03-10      0      0      0      0      0      0      0      2      3
# 2020-03-11      0      0      0      0      2      1      1      0      1
# 2020-03-12      0      0      0      0      0      0      0      0      3
# 2020-03-13      0      0      0      0      0      0      1      3      2
#
# ...

# %%
slinky_dog['date'] = pd.to_datetime(slinky_dog["date"])
slinky_dog.dtypes
# Out:
# date        datetime64[ns]
# datetime            object
# SPOSTMIN           float64
# dtype: object

# %%
slinky_dog
# Out:
#             date             datetime  SPOSTMIN
# 0     2018-06-30  2018-06-30 07:44:06     270.0
# 1     2018-06-30  2018-06-30 07:51:06     270.0
# 2     2018-06-30  2018-06-30 07:58:07     270.0
# 3     2018-06-30  2018-06-30 08:02:08     270.0
# 4     2018-06-30  2018-06-30 08:09:06     270.0
# ...          ...                  ...       ...
# 70597 2020-03-13  2020-03-13 19:51:01      55.0
# 70598 2020-03-13  2020-03-13 19:58:02      40.0
# 70599 2020-03-13  2020-03-13 20:09:02      40.0
# 70600 2020-03-13  2020-03-13 20:16:02      40.0
# 70601 2020-03-13  2020-03-13 20:23:02      35.0
#
# [70602 rows x 3 columns]

# %%
# pd.crosstab(slinky_dog.date, slinky_dog.SPOSTMIN)

# %%
slinky_dog['datetime'] = pd.to_datetime(slinky_dog["datetime"])
slinky_dog.dtypes
# Out:
# date        datetime64[ns]
# datetime    datetime64[ns]
# SPOSTMIN           float64
# dtype: object

# %%
# set date column to be index
slinky_dog.set_index('datetime', inplace = True)
slinky_dog.head()
# Out:
#                           date  SPOSTMIN
# datetime
# 2018-06-30 07:44:06 2018-06-30     270.0
# 2018-06-30 07:51:06 2018-06-30     270.0
# 2018-06-30 07:58:07 2018-06-30     270.0
# 2018-06-30 08:02:08 2018-06-30     270.0
# 2018-06-30 08:09:06 2018-06-30     270.0

# %%
slinky_dog.resample("H").mean().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 14942 entries, 2018-06-30 07:00:00 to 2020-03-13 20:00:00
# Freq: H
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SPOSTMIN  8839 non-null   float64
# dtypes: float64(1)
# memory usage: 233.5 KB

# %%
slinky_dog.resample("H").mean()
# Out:
#                        SPOSTMIN
# datetime
# 2018-06-30 07:00:00  270.000000
# 2018-06-30 08:00:00  270.000000
# 2018-06-30 09:00:00  270.000000
# 2018-06-30 10:00:00  270.000000
# 2018-06-30 11:00:00  270.000000
# 2018-06-30 12:00:00  273.000000
# 2018-06-30 13:00:00         NaN
# 2018-06-30 14:00:00  270.000000
# 2018-06-30 15:00:00  270.000000
# 2018-06-30 16:00:00  270.000000
# 2018-06-30 17:00:00  194.444444
# 2018-06-30 18:00:00  168.888889
# 2018-06-30 19:00:00  180.000000
# 2018-06-30 20:00:00  132.500000
# 2018-06-30 21:00:00  180.000000
# 2018-06-30 22:00:00  180.000000
# 2018-06-30 23:00:00  180.000000
# 2018-07-01 00:00:00         NaN
# 2018-07-01 01:00:00         NaN
# 2018-07-01 02:00:00         NaN

# %%
slinky_dog = slinky_dog.resample("H").mean().dropna()
slinky_dog
# Out:
#                        SPOSTMIN
# datetime
# 2018-06-30 07:00:00  270.000000
# 2018-06-30 08:00:00  270.000000
# 2018-06-30 09:00:00  270.000000
# 2018-06-30 10:00:00  270.000000
# 2018-06-30 11:00:00  270.000000
# ...                         ...
# 2020-03-13 16:00:00   71.875000
# 2020-03-13 17:00:00   70.000000
# 2020-03-13 18:00:00   65.555556
# 2020-03-13 19:00:00   54.375000
# 2020-03-13 20:00:00   38.333333
#
# [8839 rows x 1 columns]

# %%
slinky_dog.reset_index(level=0, inplace=True)

# %%
slinky_dog
# Out:
#                 datetime    SPOSTMIN
# 0    2018-06-30 07:00:00  270.000000
# 1    2018-06-30 08:00:00  270.000000
# 2    2018-06-30 09:00:00  270.000000
# 3    2018-06-30 10:00:00  270.000000
# 4    2018-06-30 11:00:00  270.000000
# ...                  ...         ...
# 8834 2020-03-13 16:00:00   71.875000
# 8835 2020-03-13 17:00:00   70.000000
# 8836 2020-03-13 18:00:00   65.555556
# 8837 2020-03-13 19:00:00   54.375000
# 8838 2020-03-13 20:00:00   38.333333
#
# [8839 rows x 2 columns]

# %%
slinky_dog.to_csv('../hourly_data/slinky_dog.csv', index = False)

# %%
plt.figure(figsize = (15,8))
plt.plot(slinky_dog["SPOSTMIN"])

plt.plot(slinky_dog["SPOSTMIN"].rolling(30).mean());
